# %%
from pandas import datetime
from pandas import DataFrame
from pandas import read_csv
from statsmodels.tsa.arima_model import ARIMA
from matplotlib import pyplot
from pandas.tools.plotting import autocorrelation_plot
 
def parser(x):
    return datetime.strptime('190'+x, '%Y-%m')
 
series = read_csv('../data/ts-test.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)

print(series.head())
series.plot()
pyplot.show()

print(residuals.describe())
# Out:
# ['1-02' '1-03' '1-04' '1-05' '1-06' '1-07' '1-08' '1-09' '1-10' '1-11'
#  '1-12' '2-01' '2-02' '2-03' '2-04' '2-05' '2-06' '2-07' '2-08' '2-09'
#  '2-10' '2-11' '2-12' '3-01' '3-02' '3-03' '3-04' '3-05' '3-06' '3-07'
#  '3-08' '3-09' '3-10' '3-11' '3-12'
#  'Sales of shampoo over a three year period']
# 1-02
# 1-03
# 1-04
# 1-05
# 1-06
# 1-07
# 1-08
# 1-09
# 1-10
# 1-11
# 1-12
# 2-01
# 2-02
# 2-03
# 2-04
# 2-05
# 2-06
# 2-07
# 2-08
# 2-09
# 2-10
# 2-11
# 2-12
# 3-01
# 3-02
# 3-03
# 3-04
# 3-05
# 3-06
# 3-07
# 3-08
# 3-09
# 3-10
# 3-11
# 3-12
# Sales of shampoo over a three year period
# 1-02
# 1-03
# 1-04
# 1-05
# 1-06
# 1-07
# 1-08
# 1-09
# 1-10
# 1-11
# 1-12
# 2-01
# 2-02
# 2-03
# 2-04
# 2-05
# 2-06
# 2-07
# 2-08
# 2-09
# 2-10
# 2-11
# 2-12
# 3-01
# 3-02
# 3-03
# 3-04
# 3-05
# 3-06
# 3-07
# 3-08
# 3-09
# 3-10
# 3-11
# 3-12
# Sales of shampoo over a three year period
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/envs/py3Env/lib/python3.6/site-packages/pandas/io/parsers.py in converter(*date_cols)
#    3029                 result = tools.to_datetime(
# -> 3030                     date_parser(*date_cols), errors='ignore')
#    3031                 if isinstance(result, datetime.datetime):
#
# <ipython-input-2-10323326f584> in parser(x)
#       9     print(x)
# ---> 10     return datetime.strptime('190'+x, '%Y-%m')
#      11
#
# TypeError: strptime() argument 1 must be str, not numpy.ndarray
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/envs/py3Env/lib/python3.6/site-packages/pandas/io/parsers.py in converter(*date_cols)
#    3038                                                 parser=date_parser,
# -> 3039                                                 dayfirst=dayfirst),
#    3040                         errors='ignore')
#
# pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.try_parse_dates()
#
# pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.try_parse_dates()
#
# <ipython-input-2-10323326f584> in parser(x)
#       9     print(x)
# ---> 10     return datetime.strptime('190'+x, '%Y-%m')
#      11
#
# ~/anaconda3/envs/py3Env/lib/python3.6/_strptime.py in _strptime_datetime(cls, data_string, format)
#     564     format string."""
# --> 565     tt, fraction = _strptime(data_string, format)
#     566     tzname, gmtoff = tt[-2:]
#
# ~/anaconda3/envs/py3Env/lib/python3.6/_strptime.py in _strptime(data_string, format)
#     361         raise ValueError("time data %r does not match format %r" %
# --> 362                          (data_string, format))
#     363     if len(data_string) != found.end():
#
# ValueError: time data '190Sales of shampoo over a three year period' does not match format '%Y-%m'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-10323326f584> in <module>()
#      10     return datetime.strptime('190'+x, '%Y-%m')
#      11
# ---> 12 series = read_csv('../data/ts-test.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
#      13
#      14 print(series.head())
#
# ~/anaconda3/envs/py3Env/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     707                     skip_blank_lines=skip_blank_lines)
#     708
# --> 709         return _read(filepath_or_buffer, kwds)
#     710
#     711     parser_f.__name__ = name
#
# ~/anaconda3/envs/py3Env/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     453
#     454     try:
# --> 455         data = parser.read(nrows)
#     456     finally:
#     457         parser.close()
#
# ~/anaconda3/envs/py3Env/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1067                 raise ValueError('skipfooter not supported for iteration')
#    1068
# -> 1069         ret = self._engine.read(nrows)
#    1070
#    1071         if self.options.get('as_recarray'):
#
# ~/anaconda3/envs/py3Env/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1915
#    1916             names, data = self._do_date_conversions(names, data)
# -> 1917             index, names = self._make_index(data, alldata, names)
#    1918
#    1919         # maybe create a mi on the columns
#
# ~/anaconda3/envs/py3Env/lib/python3.6/site-packages/pandas/io/parsers.py in _make_index(self, data, alldata, columns, indexnamerow)
#    1410         elif not self._has_complex_date_col:
#    1411             index = self._get_simple_index(alldata, columns)
# -> 1412             index = self._agg_index(index)
#    1413         elif self._has_complex_date_col:
#    1414             if not self._name_processed:
#
# ~/anaconda3/envs/py3Env/lib/python3.6/site-packages/pandas/io/parsers.py in _agg_index(self, index, try_parse_dates)
#    1491
#    1492             if (try_parse_dates and self._should_parse_dates(i)):
# -> 1493                 arr = self._date_conv(arr)
#    1494
#    1495             if self.na_filter:
#
# ~/anaconda3/envs/py3Env/lib/python3.6/site-packages/pandas/io/parsers.py in converter(*date_cols)
#    3040                         errors='ignore')
#    3041                 except Exception:
# -> 3042                     return generic_parser(date_parser, *date_cols)
#    3043
#    3044     return converter
#
# ~/anaconda3/envs/py3Env/lib/python3.6/site-packages/pandas/io/date_converters.py in generic_parser(parse_func, *cols)
#      37     for i in range(N):
#      38         args = [c[i] for c in cols]
# ---> 39         results[i] = parse_func(*args)
#      40
#      41     return results
#
# <ipython-input-2-10323326f584> in parser(x)
#       8 def parser(x):
#       9     print(x)
# ---> 10     return datetime.strptime('190'+x, '%Y-%m')
#      11
#      12 series = read_csv('../data/ts-test.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
#
# ~/anaconda3/envs/py3Env/lib/python3.6/_strptime.py in _strptime_datetime(cls, data_string, format)
#     563     """Return a class cls instance based on the input string and the
#     564     format string."""
# --> 565     tt, fraction = _strptime(data_string, format)
#     566     tzname, gmtoff = tt[-2:]
#     567     args = tt[:6] + (fraction,)
#
# ~/anaconda3/envs/py3Env/lib/python3.6/_strptime.py in _strptime(data_string, format)
#     360     if not found:
#     361         raise ValueError("time data %r does not match format %r" %
# --> 362                          (data_string, format))
#     363     if len(data_string) != found.end():
#     364         raise ValueError("unconverted data remains: %s" %
#
# ValueError: time data '190Sales of shampoo over a three year period' does not match format '%Y-%m'

# %%
autocorrelation_plot(series)
pyplot.show()

# %%
# fit model
model = ARIMA(series, order=(5,1,0))
model_fit = model.fit(disp=0)
print(model_fit.summary())

# %%
# plot residual errors
residuals = DataFrame(model_fit.resid)
residuals.plot()
pyplot.show()
residuals.plot(kind='kde')
pyplot.show()
